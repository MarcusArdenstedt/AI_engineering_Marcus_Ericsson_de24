# %% [markdown]
# # Structure gemini outputs with Pydantic

# %%
from google import genai


client = genai.Client()

response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents= "List a few asian soup recipes, a yummy description and list the ingresients"
)

print(response.text)
# Out:
# Here are a few delectable Asian soup recipes, each with a yummy description and a list of key ingredients to get your taste buds tingling!
#
# ---
#
# ### 1. Pho Bo (Vietnamese Beef Noodle Soup)
#
# **Yummy Description:** Imagine a comforting hug in a bowl – that's Pho Bo. It's a deeply aromatic, clear beef broth simmered for hours with warming spices like star anise, cinnamon, and cloves. This fragrant symphony cradles tender slices of rare beef, silky rice noodles, and a vibrant medley of fresh herbs and crunchy bean sprouts. Each spoonful is a harmonious blend of savory, sweet, and herbaceous notes, utterly soul-satisfying and invigorating.
#
# **Key Ingredients:**
#
# *   **Broth:** Beef bones (marrow and knuckle), oxtail (optional), yellow onion, ginger, star anise, cinnamon sticks, cloves, black cardamom pods, fish sauce, rock sugar.
# *   **Noodles:** Flat rice noodles (Bánh Phở).
# *   **Protein:** Thinly sliced raw beef (e.g., eye of round, sirloin, brisket), beef meatballs (optional).
# *   **Garnishes:** Fresh cilantro, green onions, bean sprouts, Thai basil, lime wedges, jalapeño or bird's eye chilies, hoisin sauce, Sriracha.
#
# ---
#
# ### 2. Tom Yum Goong (Thai Hot and Sour Prawn Soup)
#
# **Yummy Description:** Prepare for an exhilarating explosion of flavors! Tom Yum Goong is a vibrant, tangy, and spicy Thai masterpiece that awakens every sense. The clear, aromatic broth is infused with the zesty power of lemongrass, galangal, and kaffir lime leaves, giving it a distinctive citrusy fragrance. Plump, juicy prawns swim amidst earthy mushrooms and ripe tomatoes, all brought together with a fiery kick of chilies and a perfect balance of sour lime and savory fish sauce. It's truly a soup that dances on your palate!
#
# **Key Ingredients:**
#
# *   **Broth Base:** Chicken or prawn stock, lemongrass (bruised), galangal (sliced), kaffir lime leaves (torn), red bird's eye chilies (fresh, crushed or sliced).
# *   **Flavoring:** Fish sauce, lime juice, chili paste (Nam Prik Pao, optional but adds depth).
# *   **Protein:** Fresh prawns (shrimp).
# *   **Vegetables:** Straw mushrooms, oyster mushrooms, or button mushrooms; cherry tomatoes (halved).
# *   **Garnish:** Fresh cilantro.
#
# ---
#
# ### 3. Shoyu Ramen (Japanese Soy Sauce Ramen)
#
# **Yummy Description:** A comforting bowl of umami perfection, Shoyu Ramen is a classic for a reason. Its broth, rich yet clear, is made from chicken, pork, or dashi stock, seasoned profoundly with soy sauce (shoyu). This savory foundation embraces springy, chewy wheat noodles, topped with melt-in-your-mouth slices of tender Chashu pork belly. Every slurp is a delightful combination of textures and flavors, further enhanced by a perfectly jammy soft-boiled egg, crisp bamboo shoots, and a sprinkle of fresh green onions. It's pure, hearty satisfaction.
#
# **Key Ingredients:**
#
# *   **Broth (Dashi/Chicken/Pork):** Kombu (dried kelp), katsuobushi (bonito flakes) for Dashi; chicken bones, pork bones for richer broths.
# *   **Shoyu Tare (Flavoring Concentrate):** Soy sauce, mirin, sake, dried shiitake mushrooms (optional).
# *   **Noodles:** Fresh ramen noodles (alkaline wheat noodles).
# *   **Protein:** Chashu pork (braised pork belly or shoulder), soft-boiled Ajitama egg (marinated egg).
# *   **Garnishes:** Nori (seaweed sheets), Menma (marinated bamboo shoots), green onions (scallions), Narutomaki (fish cake, optional).
#
# ---
#
# ### 4. Laksa (Malaysian/Singaporean Curry Noodle Soup)
#
# **Yummy Description:** Prepare to be utterly captivated by Laksa, a creamy, spicy, and utterly addictive coconut curry noodle soup. Its vibrant broth is a complex blend of aromatic spices like galangal, lemongrass, turmeric, and chili, simmered in rich coconut milk to create an irresistible, fragrant base. Slurpable noodles – often a mix of thick vermicelli and thin egg noodles – are generously coated in the luscious sauce, complemented by succulent prawns, tender shredded chicken, fried tofu puffs, and a burst of freshness from bean sprouts and herbs. It's a symphony of textures and an explosion of robust, spicy-sweet flavors.
#
# **Key Ingredients:**
#
# *   **Laksa Paste (or store-bought):** Shallots, garlic, dried chilies, galangal, lemongrass, turmeric, candlenuts or macadamia nuts, belacan (shrimp paste, optional).
# *   **Broth Base:** Coconut milk, chicken or fish stock, fish sauce, sugar.
# *   **Noodles:** Thick rice vermicelli noodles and/or thin egg noodles.
# *   **Protein:** Fresh prawns/shrimp, shredded cooked chicken, fish cakes or fish balls, fried tofu puffs.
# *   **Garnishes:** Bean sprouts, hard-boiled egg (halved), fresh cilantro, Laksa leaves (Vietnamese coriander, optional), lime wedge, sambal chili paste.

# %%
response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents= """List a few asian soup recipes, a yummy description and list the ingresients.
    give med fields of 
    recipe_name: str
    description: str
    ingredients: list[str]
    
    not in markdown format"""
)


response.text
# Out:
# '{\n    "recipe_name": "Tom Yum Goong (Thai Hot & Sour Shrimp Soup)",\n    "description": "A vibrant and aromatic Thai classic, Tom Yum Goong is a symphony of sour, spicy, savory, and sweet flavors. This invigorating clear broth soup is infused with fragrant lemongrass, galangal, kaffir lime leaves, and fresh chilies, then brimming with succulent shrimp and mushrooms. It\'s an explosion of exotic taste that will awaken your senses!",\n    "ingredients": [\n        "Shrimp (peeled, deveined)",\n        "Chicken or vegetable broth",\n        "Lemongrass stalks (bruised, sliced)",\n        "Galangal (sliced)",\n        "Kaffir lime leaves (torn)",\n        "Thai bird\'s eye chilies (crushed or sliced, to taste)",\n        "Mushrooms (straw or oyster mushrooms)",\n        "Fish sauce",\n        "Lime juice",\n        "Palm sugar (optional, for balance)",\n        "Cherry tomatoes (halved)",\n        "Cilantro (for garnish)",\n        "Chili paste (Nam Prik Pao, optional)"\n    ]\n}\n\n{\n    "recipe_name": "Pho Bo (Vietnamese Beef Noodle Soup)",\n    "description": "Experience the soul-warming comfort of Pho Bo, Vietnam\'s beloved national dish. This iconic soup features a deeply savory and aromatic beef broth, simmered for hours with star anise, cloves, cinnamon, and ginger. It\'s served piping hot over delicate rice noodles, tender slices of rare beef, and a generous medley of fresh herbs like cilantro, basil, and mint, along with crisp bean sprouts and a squeeze of lime. Pure culinary bliss in a bowl!",\n    "ingredients": [\n        "Beef bones (marrow and knuckle bones)",\n        "Beef flank or brisket",\n        "Thinly sliced rare beef (sirloin or eye of round)",\n        "Rice stick noodles (banh pho)",\n        "Onions",\n        "Ginger",\n        "Star anise",\n        "Cinnamon sticks",\n        "Cloves",\n        "Black cardamom (optional)",\n        "Fish sauce",\n        "Rock sugar (or regular sugar)",\n        "Salt",\n        "Cilantro (for garnish)",\n        "Thai basil (for garnish)",\n        "Mint leaves (for garnish)",\n        "Bean sprouts (for garnish)",\n        "Lime wedges (for serving)",\n        "Jalapeño or Sriracha (for serving)",\n        "Hoisin sauce (for serving)"\n    ]\n}\n\n{\n    "recipe_name": "Chinese Hot and Sour Soup",\n    "description": "A classic Chinese appetizer that\'s anything but ordinary, this Hot and Sour Soup is a tantalizing dance of piquant and tangy flavors. The silky, savory broth is thickened to perfection and boasts a delightful complexity from white pepper, black vinegar, and a hint of sesame oil. It\'s loaded with an array of textures including tender shredded pork, bamboo shoots, wood ear mushrooms, tofu, and wisps of egg flower, making every spoonful an exciting adventure for your palate.",\n    "ingredients": [\n        "Pork tenderloin (shredded)",\n        "Chicken or vegetable broth",\n        "Firm tofu (diced)",\n        "Dried shiitake mushrooms (rehydrated, sliced)",\n        "Wood ear mushrooms (rehydrated, sliced)",\n        "Bamboo shoots (shredded)",\n        "Rice vinegar (or black vinegar)",\n        "Soy sauce",\n        "White pepper",\n        "Sesame oil",\n        "Cornstarch (for thickening)",\n        "Eggs (beaten)",\n        "Chili garlic sauce (optional, for extra heat)",\n        "Green onions (for garnish)",\n        "Salt (to taste)"\n    ]\n}'

# %%
print(response.text)
# Out:
# {
#     "recipe_name": "Tom Yum Goong (Thai Hot & Sour Shrimp Soup)",
#     "description": "A vibrant and aromatic Thai classic, Tom Yum Goong is a symphony of sour, spicy, savory, and sweet flavors. This invigorating clear broth soup is infused with fragrant lemongrass, galangal, kaffir lime leaves, and fresh chilies, then brimming with succulent shrimp and mushrooms. It's an explosion of exotic taste that will awaken your senses!",
#     "ingredients": [
#         "Shrimp (peeled, deveined)",
#         "Chicken or vegetable broth",
#         "Lemongrass stalks (bruised, sliced)",
#         "Galangal (sliced)",
#         "Kaffir lime leaves (torn)",
#         "Thai bird's eye chilies (crushed or sliced, to taste)",
#         "Mushrooms (straw or oyster mushrooms)",
#         "Fish sauce",
#         "Lime juice",
#         "Palm sugar (optional, for balance)",
#         "Cherry tomatoes (halved)",
#         "Cilantro (for garnish)",
#         "Chili paste (Nam Prik Pao, optional)"
#     ]
# }
#
# {
#     "recipe_name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#     "description": "Experience the soul-warming comfort of Pho Bo, Vietnam's beloved national dish. This iconic soup features a deeply savory and aromatic beef broth, simmered for hours with star anise, cloves, cinnamon, and ginger. It's served piping hot over delicate rice noodles, tender slices of rare beef, and a generous medley of fresh herbs like cilantro, basil, and mint, along with crisp bean sprouts and a squeeze of lime. Pure culinary bliss in a bowl!",
#     "ingredients": [
#         "Beef bones (marrow and knuckle bones)",
#         "Beef flank or brisket",
#         "Thinly sliced rare beef (sirloin or eye of round)",
#         "Rice stick noodles (banh pho)",
#         "Onions",
#         "Ginger",
#         "Star anise",
#         "Cinnamon sticks",
#         "Cloves",
#         "Black cardamom (optional)",
#         "Fish sauce",
#         "Rock sugar (or regular sugar)",
#         "Salt",
#         "Cilantro (for garnish)",
#         "Thai basil (for garnish)",
#         "Mint leaves (for garnish)",
#         "Bean sprouts (for garnish)",
#         "Lime wedges (for serving)",
#         "Jalapeño or Sriracha (for serving)",
#         "Hoisin sauce (for serving)"
#     ]
# }
#
# {
#     "recipe_name": "Chinese Hot and Sour Soup",
#     "description": "A classic Chinese appetizer that's anything but ordinary, this Hot and Sour Soup is a tantalizing dance of piquant and tangy flavors. The silky, savory broth is thickened to perfection and boasts a delightful complexity from white pepper, black vinegar, and a hint of sesame oil. It's loaded with an array of textures including tender shredded pork, bamboo shoots, wood ear mushrooms, tofu, and wisps of egg flower, making every spoonful an exciting adventure for your palate.",
#     "ingredients": [
#         "Pork tenderloin (shredded)",
#         "Chicken or vegetable broth",
#         "Firm tofu (diced)",
#         "Dried shiitake mushrooms (rehydrated, sliced)",
#         "Wood ear mushrooms (rehydrated, sliced)",
#         "Bamboo shoots (shredded)",
#         "Rice vinegar (or black vinegar)",
#         "Soy sauce",
#         "White pepper",
#         "Sesame oil",
#         "Cornstarch (for thickening)",
#         "Eggs (beaten)",
#         "Chili garlic sauce (optional, for extra heat)",
#         "Green onions (for garnish)",
#         "Salt (to taste)"
#     ]
# }

# %%
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str 
    description: str
    ingredients: list[str]
    
    
client = genai.Client()

response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents= "List a few asian soup recipes, a yummy description and list the ingredients",
    config= {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [{"recipe_name":"Tom Yum Goong","description":"A classic Thai hot and sour soup, bursting with aromatic herbs, tender shrimp, and a fiery, tangy broth that will awaken your taste buds.","ingredients":["Shrimp","Lemongrass","Galangal","Kaffir lime leaves","Mushrooms","Fish sauce","Lime juice","Chili paste","Chili peppers","Cilantro"]}, {"recipe_name":"Miso Soup","description":"A comforting and traditional Japanese soup made with a delicate dashi broth and miso paste, often served with tofu and seaweed for a light yet satisfying experience.","ingredients":["Miso paste","Dashi (seaweed and bonito flakes broth)","Tofu","Wakame seaweed","Green onions"]}, {"recipe_name":"Pho Bo","description":"A soulful Vietnamese beef noodle soup featuring a rich, aromatic broth simmered for hours, tender slices of beef, and chewy rice noodles, garnished with fresh herbs and sprouts.","ingredients":["Beef bones","Beef chuck or brisket","Rice noodles","Onions","Ginger","Star anise","Cinnamon sticks","Cardamom pods","Fish sauce","Bean sprouts","Basil","Mint","Lime","Chili peppers"]}]

# %%
recipe = response.parsed
len(recipe)
# Out:
# 3

# %%
recipe[0].description
# Out:
# 'A classic Thai hot and sour soup, bursting with aromatic herbs, tender shrimp, and a fiery, tangy broth that will awaken your taste buds.'

# %%
recipe[0].recipe_name
# Out:
# 'Tom Yum Goong'

# %%
recipe[0].ingredients
# Out:
# ['Shrimp',
#  'Lemongrass',
#  'Galangal',
#  'Kaffir lime leaves',
#  'Mushrooms',
#  'Fish sauce',
#  'Lime juice',
#  'Chili paste',
#  'Chili peppers',
#  'Cilantro']

# %% [markdown]
# ## House pricing

# %%
from typing import Literal

class Home(BaseModel):
    price: int
    monthly_fee: int
    living_area: float
    number_rooms: int
    type: Literal["apartment", "house"]
    address: str
    
response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents= """
    List 50 apartments and houses in Sweden with their monthly fee, price,
    living area, number of rooms, address, type if it is apartment or house. All currencies are in
    SEK. Data should be simulation of swedish housing.
    """,
    config= {"response_mime_type": "application/json", "response_schema": list[Home]}
)

# %%
homes = response.parsed
len(homes)
# Out:
# 50

# %%
homes[0].price, homes[0].address
# Out:
# (4500000, 'Storgatan 12B, Stockholm')

# %%
homes[0].__dict__
# Out:
# {'price': 4500000,
#  'monthly_fee': 3800,
#  'living_area': 65.5,
#  'number_rooms': 3,
#  'type': 'apartment',
#  'address': 'Storgatan 12B, Stockholm'}

# %%
import pandas as pd

df = pd.DataFrame([home.__dict__ for home in homes])

df.head()
# Out:
#      price  monthly_fee  living_area  number_rooms       type  \
# 0  4500000         3800         65.5             3  apartment
# 1  8200000         4900        120.0             5      house
# 2  2850000         2900         42.0             2  apartment
# 3  6750000         3400        180.0             7      house
# 4  3100000         3200         58.0             2  apartment
#
#                      address
# 0   Storgatan 12B, Stockholm
# 1     Björkvägen 27, Uppsala
# 2  Södra Långgatan 7A, Malmö
# 3       Ekallén 15, Göteborg
# 4       Vasagatan 33, Örebro

# %%
cheap_houses = df.query("price < 7_000_000 and type == 'house'")
cheap_houses
# Out:
#       price  monthly_fee  living_area  number_rooms   type  \
# 3   6750000         3400        180.0             7  house
# 7   5800000         3100        140.0             6  house
# 13  6300000         3700        155.0             5  house
# 21  5500000         3000        130.0             5  house
# 27  6000000         3200        145.0             5  house
# 31  6800000         3800        160.0             6  house
# 41  5700000         3300        135.0             5  house
# 49  6200000         3600        150.0             5  house
#
#                         address
# 3          Ekallén 15, Göteborg
# 7      Äppelvägen 19, Linköping
# 13  Tallbacksvägen 7, Jönköping
# 21  Vintergatan 5, Kristianstad
# 27    Gröna Vägen 8, Skellefteå
# 31        Pilvägen 21, Halmstad
# 41     Kastanjeallén 7, Uppsala
# 49         Fasanvägen 22, Falun

# %%
cheap_houses.to_csv("cheap_houses.csv", index= False)
