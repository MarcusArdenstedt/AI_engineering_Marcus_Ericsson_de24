# %% [markdown]
# # Structure gemini outputs in robust way

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""
    List a few asian soups recipes, a yummy description,
    list the ingredients
    """
)

print(response.text)
# Out:
# Here are a few incredibly delicious Asian soup recipes, each with a mouth-watering description and a list of key ingredients!
#
# ---
#
# ### 1. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **Yummy Description:**
# A soul-warming symphony of flavors, Vietnamese Pho Bo features a deeply aromatic, slow-simmered beef broth infused with star anise, cloves, and ginger. It's brimming with tender slices of beef (often thinly sliced raw beef that cooks in the hot broth), slippery rice noodles, and a vibrant medley of fresh herbs like cilantro and Thai basil, along with crunchy bean sprouts, lime, and chili for a truly invigorating and comforting experience. Each spoonful is a journey of complex spices, savory beef, and refreshing freshness.
#
# **Key Ingredients:**
# *   **For the Broth:** Beef bones (knuckles, oxtail), whole onions, ginger, star anise, cinnamon stick, black cardamom pods, cloves, coriander seeds, fish sauce, rock sugar, salt.
# *   **For Serving:**
#     *   Thinly sliced raw beef (e.g., brisket, round steak, eye of round)
#     *   Flat rice noodles (banh pho)
#     *   Thinly sliced white or yellow onion
#     *   Chopped green onions
#     *   Fresh cilantro
# *   **Garnishes (essential for the full experience):**
#     *   Bean sprouts
#     *   Fresh Thai basil leaves
#     *   Lime wedges
#     *   Sliced jalapeño or serrano peppers
#     *   Hoisin sauce (for dipping or adding to broth)
#     *   Sriracha (for heat)
#
# ---
#
# ### 2. Thai Tom Yum Goong (Hot & Sour Prawn Soup)
#
# **Yummy Description:**
# Prepare for a thrilling explosion of zesty, spicy, and sour notes! Tom Yum Goong is Thailand's iconic hot and sour soup, bursting with the fragrant essence of bruised lemongrass, thinly sliced galangal, and torn kaffir lime leaves. Succulent, plump prawns swim in a vibrant, chili-infused broth, often accompanied by straw mushrooms or oyster mushrooms. It's a bright, invigorating, and utterly addictive soup that wakes up every taste bud!
#
# **Key Ingredients:**
# *   **For the Broth Base:** Chicken or vegetable broth, fresh lemongrass (bruised), fresh galangal (sliced), kaffir lime leaves (torn), bird's eye chilies (crushed or sliced), fish sauce, fresh lime juice, a pinch of sugar.
# *   **Main Protein:** Fresh prawns (shrimp), shelled and deveined.
# *   **Vegetables:** Straw mushrooms, oyster mushrooms, or button mushrooms.
# *   **Garnish:** Fresh cilantro leaves, a swirl of chili oil (optional).
#
# ---
#
# ### 3. Malaysian/Singaporean Laksa (Spicy Coconut Noodle Soup)
#
# **Yummy Description:**
# Dive into the opulent richness of Laksa! This vibrant, creamy, and spicy coconut curry noodle soup is a Malaysian and Singaporean masterpiece. Its complex broth, simmered with a potent blend of aromatic spices (the Laksa paste) and rich coconut milk, envelops a generous mix of thick wheat or rice vermicelli noodles. It's generously topped with a medley of seafood (like prawns and fish cake), shredded chicken, tofu puffs, crunchy bean sprouts, and fresh herbs, making every spoonful an exotic delight.
#
# **Key Ingredients:**
# *   **Laksa Paste (often store-bought or homemade):** Dried red chilies, shallots, garlic, galangal, lemongrass, turmeric, coriander, cumin, candlenuts (optional), shrimp paste (belacan).
# *   **For the Broth:** Full-fat coconut milk, chicken or fish broth, Laksa paste, a touch of tamarind paste (optional), sugar, salt, fish sauce.
# *   **Noodles:** Thick rice vermicelli AND/OR Hokkien noodles (yellow wheat noodles).
# *   **Toppings:**
#     *   Fresh prawns
#     *   Cooked shredded chicken
#     *   Fish cakes (sliced)
#     *   Fried tofu puffs (absorb the broth beautifully!)
#     *   Bean sprouts
#     *   Hard-boiled egg (halved)
#     *   Cucumber (julienned)
#     *   Laksa leaves (Vietnamese coriander/rau ram - if available)
#     *   Sambal (chili paste) for extra heat
#
# ---
#
# ### 4. Chinese Wonton Noodle Soup
#
# **Yummy Description:**
# The ultimate comfort in a bowl, Cantonese Wonton Noodle Soup is a delicately savory and utterly satisfying experience. Plump, silken wontons, typically filled with seasoned ground pork and succulent shrimp, float in a light yet deeply flavorful clear broth, often accompanied by springy egg noodles and crisp Chinese greens like bok choy. It's a comforting hug, a perfectly balanced meal that warms you from the inside out with its subtle elegance.
#
# **Key Ingredients:**
# *   **For the Wontons:**
#     *   Ground pork (or a mix of pork and shrimp)
#     *   Minced shrimp
#     *   Soy sauce, sesame oil, white pepper, cornstarch, finely chopped green onions
#     *   Wonton wrappers
# *   **For the Broth:**
#     *   Good quality chicken broth (or homemade chicken stock)
#     *   Ginger slices, white parts of green onions, salt, white pepper
# *   **For Serving:**
#     *   Thin egg noodles (wonton noodles)
#     *   Bok choy or Chinese broccoli
# *   **Garnish:** Chopped green onions (green parts), a drizzle of sesame oil.

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""
    List a few asian soups recipes, a yummy description,
    and list the ingredients. Structure it in json format
    """
)

print(response.text)
# Out:
# ```json
# [
#   {
#     "name": "Tom Yum Goong",
#     "cuisine": "Thai",
#     "description": "A vibrant, spicy, and sour Thai hot and sour soup bursting with aromatic herbs. It's an exhilarating explosion of flavors – zesty lime, fiery chili, fragrant lemongrass, and galangal, all swimming with succulent shrimp. Pure tropical delight!",
#     "ingredients": [
#       "2 cups chicken or vegetable broth",
#       "8-10 large shrimp, peeled and deveined",
#       "1 stalk lemongrass, bruised and sliced",
#       "1 inch galangal, sliced",
#       "3-4 kaffir lime leaves, torn",
#       "1/2 cup straw mushrooms or oyster mushrooms",
#       "2-3 small red chilies, crushed (or 1-2 tbsp chili paste)",
#       "2-3 tbsp fish sauce",
#       "2-3 tbsp lime juice",
#       "1 tsp sugar (optional, to balance flavors)",
#       "Fresh cilantro, for garnish"
#     ]
#   },
#   {
#     "name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#     "cuisine": "Vietnamese",
#     "description": "An iconic, deeply aromatic Vietnamese beef noodle soup, celebrated for its complex, savory broth simmered for hours with star anise, cloves, and cinnamon. Served with slippery rice noodles, tender slices of beef, and a vibrant platter of fresh herbs and sprouts, it's a soul-warming culinary embrace.",
#     "ingredients": [
#       "2-3 lbs beef bones (knuckle, marrow, oxtail)",
#       "1-2 lbs beef flank steak or brisket (thinly sliced)",
#       "1 large onion, halved and charred",
#       "4-inch ginger, sliced and charred",
#       "4-5 star anise",
#       "4-5 whole cloves",
#       "1 cinnamon stick",
#       "1 black cardamom pod",
#       "2-3 tbsp fish sauce",
#       "1 tbsp sugar",
#       "Salt to taste",
#       "1 lb fresh rice noodles (banh pho)",
#       "Garnish: Bean sprouts, fresh basil, cilantro, lime wedges, sliced jalapeños, hoisin sauce, Sriracha"
#     ]
#   },
#   {
#     "name": "Miso Soup",
#     "cuisine": "Japanese",
#     "description": "The ultimate Japanese comfort in a bowl. This delicate, savory soup features a rich dashi broth infused with umami-packed miso paste, tender cubes of silken tofu, and delicate strands of wakame seaweed. Simple yet profoundly satisfying, it's a warm hug for your senses, perfect any time.",
#     "ingredients": [
#       "4 cups dashi (Japanese soup stock from bonito flakes and kombu)",
#       "3-4 tbsp miso paste (white or red, depending on preference)",
#       "4 oz silken tofu, cut into 1/2-inch cubes",
#       "2 tbsp dried wakame seaweed, rehydrated and chopped",
#       "2 green onions, thinly sliced (for garnish)"
#     ]
#   },
#   {
#     "name": "Kimchi Jjigae (Kimchi Stew)",
#     "cuisine": "Korean",
#     "description": "A fiery, robust Korean stew that warms you from the inside out! This deeply flavorful dish is built on fermented kimchi, giving it a wonderfully tangy and spicy kick. Braised with tender pork (or tofu), soft tofu, and sometimes vegetables, it’s a hearty, satisfying bowl perfect for any day.",
#     "ingredients": [
#       "1.5 cups aged kimchi, chopped",
#       "1/2 lb pork belly or shoulder, thinly sliced (or firm tofu)",
#       "1/2 block soft tofu, cubed",
#       "1/2 onion, sliced",
#       "2 cloves garlic, minced",
#       "1-2 tbsp gochugaru (Korean chili flakes)",
#       "1 tbsp gochujang (Korean chili paste)",
#       "1/4 cup kimchi juice (from the kimchi container)",
#       "2-3 cups anchovy broth or water",
#       "1 tsp sugar (optional)",
#       "1 green onion, chopped (for garnish)",
#       "Optional: Enoki mushrooms, rice cakes"
#     ]
#   },
#   {
#     "name": "Laksa (Curry Laksa)",
#     "cuisine": "Malaysian/Singaporean",
#     "description": "An incredibly rich and complex Southeast Asian noodle soup, Laksa is a creamy, spicy, and utterly addictive coconut curry broth. Packed with chewy noodles, succulent shrimp, fish cakes, and tofu puffs, each spoonful is an exotic journey of flavors – savory, sweet, spicy, and herbaceous.",
#     "ingredients": [
#       "2-3 tbsp Laksa paste (store-bought or homemade)",
#       "4 cups chicken or shrimp broth",
#       "1 (13.5 oz) can coconut milk",
#       "1/2 lb shrimp, peeled and deveined",
#       "1/4 lb fish cakes, sliced",
#       "6-8 tofu puffs (tau pok)",
#       "1 cup bean sprouts",
#       "8 oz fresh rice vermicelli noodles and/or thick wheat noodles",
#       "1-2 tbsp cooking oil",
#       "Salt and sugar to taste",
#       "Garnish: Fresh cilantro, sliced red chilies, lime wedges, a drizzle of chili oil"
#     ]
#   }
# ]
# ```

# %%
print(response.text.strip("```json"))
# Out:
# [
#   {
#     "name": "Tom Yum Goong",
#     "cuisine": "Thai",
#     "description": "A vibrant, spicy, and sour Thai hot and sour soup bursting with aromatic herbs. It's an exhilarating explosion of flavors – zesty lime, fiery chili, fragrant lemongrass, and galangal, all swimming with succulent shrimp. Pure tropical delight!",
#     "ingredients": [
#       "2 cups chicken or vegetable broth",
#       "8-10 large shrimp, peeled and deveined",
#       "1 stalk lemongrass, bruised and sliced",
#       "1 inch galangal, sliced",
#       "3-4 kaffir lime leaves, torn",
#       "1/2 cup straw mushrooms or oyster mushrooms",
#       "2-3 small red chilies, crushed (or 1-2 tbsp chili paste)",
#       "2-3 tbsp fish sauce",
#       "2-3 tbsp lime juice",
#       "1 tsp sugar (optional, to balance flavors)",
#       "Fresh cilantro, for garnish"
#     ]
#   },
#   {
#     "name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#     "cuisine": "Vietnamese",
#     "description": "An iconic, deeply aromatic Vietnamese beef noodle soup, celebrated for its complex, savory broth simmered for hours with star anise, cloves, and cinnamon. Served with slippery rice noodles, tender slices of beef, and a vibrant platter of fresh herbs and sprouts, it's a soul-warming culinary embrace.",
#     "ingredients": [
#       "2-3 lbs beef bones (knuckle, marrow, oxtail)",
#       "1-2 lbs beef flank steak or brisket (thinly sliced)",
#       "1 large onion, halved and charred",
#       "4-inch ginger, sliced and charred",
#       "4-5 star anise",
#       "4-5 whole cloves",
#       "1 cinnamon stick",
#       "1 black cardamom pod",
#       "2-3 tbsp fish sauce",
#       "1 tbsp sugar",
#       "Salt to taste",
#       "1 lb fresh rice noodles (banh pho)",
#       "Garnish: Bean sprouts, fresh basil, cilantro, lime wedges, sliced jalapeños, hoisin sauce, Sriracha"
#     ]
#   },
#   {
#     "name": "Miso Soup",
#     "cuisine": "Japanese",
#     "description": "The ultimate Japanese comfort in a bowl. This delicate, savory soup features a rich dashi broth infused with umami-packed miso paste, tender cubes of silken tofu, and delicate strands of wakame seaweed. Simple yet profoundly satisfying, it's a warm hug for your senses, perfect any time.",
#     "ingredients": [
#       "4 cups dashi (Japanese soup stock from bonito flakes and kombu)",
#       "3-4 tbsp miso paste (white or red, depending on preference)",
#       "4 oz silken tofu, cut into 1/2-inch cubes",
#       "2 tbsp dried wakame seaweed, rehydrated and chopped",
#       "2 green onions, thinly sliced (for garnish)"
#     ]
#   },
#   {
#     "name": "Kimchi Jjigae (Kimchi Stew)",
#     "cuisine": "Korean",
#     "description": "A fiery, robust Korean stew that warms you from the inside out! This deeply flavorful dish is built on fermented kimchi, giving it a wonderfully tangy and spicy kick. Braised with tender pork (or tofu), soft tofu, and sometimes vegetables, it’s a hearty, satisfying bowl perfect for any day.",
#     "ingredients": [
#       "1.5 cups aged kimchi, chopped",
#       "1/2 lb pork belly or shoulder, thinly sliced (or firm tofu)",
#       "1/2 block soft tofu, cubed",
#       "1/2 onion, sliced",
#       "2 cloves garlic, minced",
#       "1-2 tbsp gochugaru (Korean chili flakes)",
#       "1 tbsp gochujang (Korean chili paste)",
#       "1/4 cup kimchi juice (from the kimchi container)",
#       "2-3 cups anchovy broth or water",
#       "1 tsp sugar (optional)",
#       "1 green onion, chopped (for garnish)",
#       "Optional: Enoki mushrooms, rice cakes"
#     ]
#   },
#   {
#     "name": "Laksa (Curry Laksa)",
#     "cuisine": "Malaysian/Singaporean",
#     "description": "An incredibly rich and complex Southeast Asian noodle soup, Laksa is a creamy, spicy, and utterly addictive coconut curry broth. Packed with chewy noodles, succulent shrimp, fish cakes, and tofu puffs, each spoonful is an exotic journey of flavors – savory, sweet, spicy, and herbaceous.",
#     "ingredients": [
#       "2-3 tbsp Laksa paste (store-bought or homemade)",
#       "4 cups chicken or shrimp broth",
#       "1 (13.5 oz) can coconut milk",
#       "1/2 lb shrimp, peeled and deveined",
#       "1/4 lb fish cakes, sliced",
#       "6-8 tofu puffs (tau pok)",
#       "1 cup bean sprouts",
#       "8 oz fresh rice vermicelli noodles and/or thick wheat noodles",
#       "1-2 tbsp cooking oil",
#       "Salt and sugar to taste",
#       "Garnish: Fresh cilantro, sliced red chilies, lime wedges, a drizzle of chili oil"
#     ]
#   }
# ]

# %%
from pydantic import BaseModel 
from google import genai


class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingredients: list[str]


client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""
    List a few asian soups recipes, a yummy description,
    list the ingredients
    """,
    config= {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)


print(response.text)
# Out:
# [{"recipe_name":"Tom Yum Goong","description":"A classic Thai hot and sour soup, bursting with aromatic herbs, spicy chilies, and plump shrimp. It's a vibrant and refreshing dish with a perfect balance of sweet, sour, salty, and spicy flavors.","ingredients":["Shrimp","Lemongrass","Galangal","Kaffir lime leaves","Mushrooms","Fish sauce","Lime juice","Chili paste (optional)","Cilantro","Bird's eye chilies"]}, {"recipe_name":"Miso Soup","description":"A comforting and traditional Japanese soup made with dashi (a savory stock) and miso paste, often served with soft tofu, rehydrated wakame seaweed, and thinly sliced scallions. It's a warm, umami-rich, and incredibly soothing dish.","ingredients":["Dashi stock","Miso paste","Tofu (silken or firm)","Wakame seaweed","Scallions"]}, {"recipe_name":"Pho Bo (Vietnamese Beef Noodle Soup)","description":"Vietnam's iconic national dish, a deeply aromatic and flavorful beef noodle soup. It features a clear, savory broth simmered with spices, tender slices of beef, flat rice noodles, and a medley of fresh herbs and crisp bean sprouts.","ingredients":["Beef bones","Beef flank steak","Rice noodles","Onions","Ginger","Star anise","Cinnamon stick","Cloves","Cardamom pods","Fish sauce","Bean sprouts","Basil","Cilantro","Lime wedges","Jalapeño slices"]}]

# %%
recipes = response.parsed
type(recipes), len(recipes)
# Out:
# (list, 3)

# %%
recipes[0]
# Out:
# Recipe(recipe_name='Tom Yum Goong', description="A classic Thai hot and sour soup, bursting with aromatic herbs, spicy chilies, and plump shrimp. It's a vibrant and refreshing dish with a perfect balance of sweet, sour, salty, and spicy flavors.", ingredients=['Shrimp', 'Lemongrass', 'Galangal', 'Kaffir lime leaves', 'Mushrooms', 'Fish sauce', 'Lime juice', 'Chili paste (optional)', 'Cilantro', "Bird's eye chilies"])

# %%
recipes[-1].recipe_name, recipes[-1].ingredients
# Out:
# ('Pho Bo (Vietnamese Beef Noodle Soup)',
#  ['Beef bones',
#   'Beef flank steak',
#   'Rice noodles',
#   'Onions',
#   'Ginger',
#   'Star anise',
#   'Cinnamon stick',
#   'Cloves',
#   'Cardamom pods',
#   'Fish sauce',
#   'Bean sprouts',
#   'Basil',
#   'Cilantro',
#   'Lime wedges',
#   'Jalapeño slices'])

# %% [markdown]
# ## Simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int
    monthly_fee: int
    living_area: float
    number_rooms: float
    address: str
    type: Literal["apartment", "house"]
    
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""List 50 apartments and houses in Sweden with their monthly_fee, their price, living area, 
    number of rooms, address, type if it is apartment or house. 
    All currencies are in SEK.""",
    config= {"response_mime_type": "application/json", "response_schema": list[Home]}
)



homes = response.text
homes[:3]
# Out:
# '[{"'

# %%
import pandas as pd

df = pd.DataFrame([dict(home) for home in homes])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 import pandas as pd
# ----> 3 df = pd.DataFrame([dict(home) for home in homes])
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
df.query("price < 2_000_000")
