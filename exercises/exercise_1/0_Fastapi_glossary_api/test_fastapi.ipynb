# %%
import requests

url= "http://127.0.0.1:8000/glossary"
r = requests.get(url)
r.raise_for_status()

print(r.json())
# Out:
# [{'id': 1, 'word': 'path parameter', 'meaning': 'Request parameters embedded in the URL path to identify a resource (variable part of the endpoint path). Example: /users/{user_id}.'}, {'id': 2, 'word': 'endpoint (route)', 'meaning': 'A URL path in the API that accepts HTTP requests (e.g., /items, /users/{id}).'}, {'id': 3, 'word': 'query parameter', 'meaning': 'Additional keyâ€“value pairs after ? in the URL, used for filtering or searching.'}, {'id': 4, 'word': 'request body', 'meaning': 'Data sent with POST/PUT/PATCH requests, usually JSON.'}, {'id': 5, 'word': 'uvicorn', 'meaning': 'ASGI web server used to run FastAPI apps. Command: uvicorn main:app'}, {'id': 6, 'word': '%20', 'meaning': 'URL-encoded space character used in URL paths and query strings.'}, {'id': 7, 'word': 'Field (pydantic)', 'meaning': 'Function to add metadata and validation constraints to model fields (defaults, rules, descriptions, etc.).'}, {'id': 8, 'word': 'DTO', 'meaning': 'Data Transfer Objectâ€”an object
# ...

# %%
test_data = {"1": "apple", "2": "orange", "3": "pear"}

for i, item in enumerate(test_data.values()):
    print(f"{i}: {item}")
# Out:
# 0: apple
# 1: orange
# 2: pear
